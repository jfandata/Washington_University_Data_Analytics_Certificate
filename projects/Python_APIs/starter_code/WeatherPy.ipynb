# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy #change the kernal to Python Anaconda and it works, otherwise get Module error

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6175769c487d> in <module>()
#       4
#       5 # Create a set of random lat and lng combinations
# ----> 6 lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
#       7 lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
#       8 lat_lngs = zip(lats, lngs)
#
# NameError: name 'np' is not defined

# %%
# Print the city count to confirm sufficient count
print (len(cities))
#print(cities)
cities_df=pd.DataFrame(cities)
#print(cities_df)
len(cities_df[0].unique()) #check for duplicates
cities_df.rename(columns={cities_df.columns[0]:"city_name"}, inplace=True) #rename column [0] to city_name
print(cities_df)
len(cities_df["city_name"].value_counts())
# Out:
# 596
#                     city_name
# 0                   busselton
# 1                        hilo
# 2                       vaini
# 3                kruisfontein
# 4                attawapiskat
# 5                   upernavik
# 6                      tiarei
# 7                     rikitea
# 8                       kapaa
# 9                    plouzane
# 10             ribeira grande
# 11               mount vernon
# 12                      herne
# 13                   thompson
# 14                 bredasdorp
# 15                      yanam
# 16                       hami
# 17                 chokurdakh
# 18                 nikolskoye
# 19                     laguna
# 20                   kargasok
# 21                  jamestown
# 22                    vaitupu
# 23                new norfolk
# 24                     sorong
# 25                     barrow
# 26               punta arenas
# 27                  hithadhoo
# 28                 vila velha
# 29                    mataura
# ..                        ...
# 566  sao jose da coroa grande
# 567               farafangana
# 568              inderborskiy
# 569                     awash
# 570                    toftir
# 571                     salym
# 572           puerto ayacucho
# 573              wladyslawowo
# 574            vestmannaeyjar
# 575                    taltal
# 576                      tezu
# 577                 oriximina
# 578                     yumen
# 579                saryshagan
# 580                    beyneu
# 581                     asosa
# 582                   copiapo
# 583                      tara
# 584                  ubaitaba
# 585                     arman
# 586                 mackenzie
# 587               krasni okny
# 588                  freeport
# 589                  bur gabo
# 590                      auki
# 591                   satitoa
# 592                 kholodnyy
# 593                  coos bay
# 594        san jose de gracia
# 595                     vardo
#
# [596 rows x 1 columns]
# 596

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#df to store values from API calls
#set up DataFrame to hold the response info
column_names=["City", "Cloudiness", "Country", "Date", "Humidity", 
              "Lat", "Lng", "Max Temp", "Wind Speed"]
owmCities_df=pd.DataFrame(columns=column_names)

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}&appid={api_key}&units={units}&q="

#test to see the url works
response = requests.get(query_url)
print(response.status_code)

row_count=1
print ("Beginning Data Retrieval")
print("------------------------")
for index, row in cities_df.iterrows():
    city = row["city_name"]
    response = requests.get(query_url + city).json()
    if response["cod"] == "404":
        print("City not found, skip...")
        
    
    else:
        owmCities_df.set_value(index, "City", response["name"])
        owmCities_df.set_value(index, "Cloudiness", response["clouds"]["all"])
        owmCities_df.set_value(index, "Country", response["sys"]["country"])
        owmCities_df.set_value(index, "Date", response["dt"])
        owmCities_df.set_value(index, "Humidity", response["main"]["humidity"])
        owmCities_df.set_value(index, "Lat", response["coord"]["lat"])
        owmCities_df.set_value(index, "Lng", response["coord"]["lon"])
        owmCities_df.set_value(index, "Max Temp", response["main"]["temp_max"])
        owmCities_df.set_value(index, "Wind Speed", response["wind"]["speed"])
        
        print("Processing Record " , row_count, '| ' , response["name"])
        row_count += 1
# Out:
# 400
# Beginning Data Retrieval
# ------------------------
# Processing Record  1 |  Busselton
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\JF\ANACONDA\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record  2 |  Hilo
# Processing Record  3 |  Vaini
# Processing Record  4 |  Kruisfontein
# City not found, skip...
# Processing Record  5 |  Upernavik
# Processing Record  6 |  Tiarei
# Processing Record  7 |  Rikitea
# Processing Record  8 |  Kapaa
# Processing Record  9 |  Plouzane
# Processing Record  10 |  Ribeira Grande
# Processing Record  11 |  Mount Vernon
# Processing Record  12 |  Herne
# Processing Record  13 |  Thompson
# Processing Record  14 |  Bredasdorp
# Processing Record  15 |  Yanam
# Processing Record  16 |  Hami
# Processing Record  17 |  Chokurdakh
# Processing Record  18 |  Nikolskoye
# Processing Record  19 |  Laguna
# Processing Record  20 |  Kargasok
# Processing Record  21 |  Jamestown
# City not found, skip...
# Processing Record  22 |  New Norfolk
# Processing Record  23 |  Sorong
# Processing Record  24 |  Barrow
# Processing Record  25 |  Punta Arenas
# Processing Record  26 |  Hithadhoo
# Processing Record  27 |  Vila Velha
# Processing Record  28 |  Mataura
# Processing Record  29 |  Derzhavinsk
# Processing Record  30 |  Cape Town
# Processing Record  31 |  Soyo
# Processing Record  32 |  Ritchie
# Processing Record  33 |  Karratha
# Processing Record  34 |  Butaritari
# Processing Record  35 |  Qaanaaq
# Processing Record  36 |  Hermanus
# Processing Record  37 |  Port Lincoln
# Processing Record  38 |  Columbia
# City not found, skip...
# Processing Record  39 |  Ambulu
# Processing Record  40 |  Puerto Ayora
# Processing Record  41 |  Sao Filipe
# Processing Record  42 |  Salalah
# Processing Record  43 |  Fairbanks
# Processing Record  44 |  Qinhuangdao
# Processing Record  45 |  Eyrarbakki
# Processing Record  46 |  Saint-Philippe
# Processing Record  47 |  Kavieng
# Processing Record  48 |  Albany
# Processing Record  49 |  Grand Gaube
# Processing Record  50 |  Norman Wells
# City not found, skip...
# Processing Record  51 |  Poum
# Processing Record  52 |  Isangel
# Processing Record  53 |  Yellowknife
# Processing Record  54 |  Paris
# Processing Record  55 |  Suez
# City not found, skip...
# City not found, skip...
# City not found, skip...
# Processing Record  56 |  Solwezi
# Processing Record  57 |  Japura
# Processing Record  58 |  Wucheng
# City not found, skip...
# Processing Record  59 |  Camacha
# Processing Record  60 |  Castro
# Processing Record  61 |  Vityazevo
# Processing Record  62 |  Sangar
# Processing Record  63 |  Hualmay
# Processing Record  64 |  Iqaluit
# City not found, skip...
# Processing Record  65 |  Lynn Haven
# Processing Record  66 |  Burhaniye
# City not found, skip...
# Processing Record  67 |  Galle
# Processing Record  68 |  Razdolnoye
# Processing Record  69 |  Cairns
# Processing Record  70 |  Torbay
# Processing Record  71 |  Husavik
# Processing Record  72 |  Ndungu
# Processing Record  73 |  Port Alfred
# Processing Record  74 |  Sinnamary
# Processing Record  75 |  Beringovskiy
# Processing Record  76 |  Hunchun
# Processing Record  77 |  Yakima
# Processing Record  78 |  Bjornevatn
# Processing Record  79 |  Voh
# Processing Record  80 |  Tuktoyaktuk
# Processing Record  81 |  Dikson
# Processing Record  82 |  Pangoa
# Processing Record  83 |  Ushuaia
# Processing Record  84 |  Awjilah
# Processing Record  85 |  Necochea
# Processing Record  86 |  Mirnyy
# Processing Record  87 |  Ilulissat
# Processing Record  88 |  Mogadishu
# Processing Record  89 |  Byron Bay
# Processing Record  90 |  Christchurch
# Processing Record  91 |  Constitucion
# Processing Record  92 |  Gambela
# Processing Record  93 |  Bethel
# Processing Record  94 |  Semikarakorsk
# Processing Record  95 |  Havoysund
# Processing Record  96 |  Luderitz
# Processing Record  97 |  Lagoa
# Processing Record  98 |  Coihaique
# Processing Record  99 |  Grenville
# Processing Record  100 |  Makakilo City
# Processing Record  101 |  Margate
# Processing Record  102 |  Deputatskiy
# City not found, skip...
# Processing Record  103 |  Bandarbeyla
# Processing Record  104 |  Barra
# Processing Record  105 |  Kaura Namoda
# Processing Record  106 |  Airai
# Processing Record  107 |  Saint George
# Processing Record  108 |  Rome
# Processing Record  109 |  Sawakin
# Processing Record  110 |  Baykit
# City not found, skip...
# Processing Record  111 |  Kahului
# Processing Record  112 |  Maldonado
# City not found, skip...
# City not found, skip...
# Processing Record  113 |  Talnakh
# Processing Record  114 |  Talaya
# Processing Record  115 |  Dolgoderevenskoye
# Processing Record  116 |  Klaksvik
# Processing Record  117 |  Los Llanos de Aridane
# Processing Record  118 |  Bubaque
# Processing Record  119 |  Lata
# Processing Record  120 |  Borogontsy
# Processing Record  121 |  Oeiras do Para
# Processing Record  122 |  Viking
# Processing Record  123 |  Aklavik
# Processing Record  124 |  Soverato
# Processing Record  125 |  Bereda
# Processing Record  126 |  Atuona
# Processing Record  127 |  Novyy Urengoy
# Processing Record  128 |  Basqal
# Processing Record  129 |  Paso de los Toros
# Processing Record  130 |  Shache
# Processing Record  131 |  Khurba
# Processing Record  132 |  Ilinskiy
# City not found, skip...
# Processing Record  133 |  Kholm
# Processing Record  134 |  Brae
# Processing Record  135 |  Pevek
# Processing Record  136 |  Goderich
# City not found, skip...
# Processing Record  137 |  Tiksi
# City not found, skip...
# Processing Record  138 |  Havelock
# Processing Record  139 |  Luanda
# Processing Record  140 |  Kommunar
# Processing Record  141 |  Faya
# City not found, skip...
# Processing Record  142 |  Codrington
# City not found, skip...
# Processing Record  143 |  Nouadhibou
# Processing Record  144 |  Agadez
# Processing Record  145 |  Richards Bay
# Processing Record  146 |  Ixtapa
# Processing Record  147 |  Viedma
# Processing Record  148 |  Mahebourg
# Processing Record  149 |  Avera
# Processing Record  150 |  Takoradi
# Processing Record  151 |  Khatanga
# City not found, skip...
# Processing Record  152 |  Bonfim
# Processing Record  153 |  Bluff
# Processing Record  154 |  Batagay-Alyta
# Processing Record  155 |  Rosarito
# Processing Record  156 |  Uddevalla
# Processing Record  157 |  Salinas
# Processing Record  158 |  Cherskiy
# Processing Record  159 |  Peleduy
# Processing Record  160 |  Sao Felix do Xingu
# Processing Record  161 |  Vigrestad
# Processing Record  162 |  Moose Factory
# Processing Record  163 |  Pisco
# Processing Record  164 |  Faanui
# Processing Record  165 |  Mount Gambier
# Processing Record  166 |  Carnarvon
# City not found, skip...
# Processing Record  167 |  Gadung
# Processing Record  168 |  Aksarka
# Processing Record  169 |  Hobart
# Processing Record  170 |  Muros
# Processing Record  171 |  Talara
# Processing Record  172 |  Wanaka
# Processing Record  173 |  Sandy Bay
# Processing Record  174 |  Maracacume
# Processing Record  175 |  Iskateley
# Processing Record  176 |  Avarua
# Processing Record  177 |  Dingle
# Processing Record  178 |  Bolitoc
# Processing Record  179 |  Olinda
# Processing Record  180 |  Snizhne
# City not found, skip...
# Processing Record  181 |  Naryan-Mar
# Processing Record  182 |  Ostersund
# Processing Record  183 |  Axim
# Processing Record  184 |  Arraial do Cabo
# Processing Record  185 |  Westport
# Processing Record  186 |  Poshekhonye
# City not found, skip...
# Processing Record  187 |  Gannan
# Processing Record  188 |  Impfondo
# Processing Record  189 |  Clyde River
# Processing Record  190 |  Leningradskiy
# Processing Record  191 |  Aswan
# Processing Record  192 |  Severobaykalsk
# Processing Record  193 |  Dehui
# Processing Record  194 |  Tasiilaq
# Processing Record  195 |  Mount Isa
# Processing Record  196 |  Tanout
# Processing Record  197 |  The Pas
# Processing Record  198 |  Waipawa
# Processing Record  199 |  Natal
# City not found, skip...
# Processing Record  200 |  Praia da Vitoria
# Processing Record  201 |  King City
# Processing Record  202 |  Oranjemund
# Processing Record  203 |  Doha
# Processing Record  204 |  Bambous Virieux
# Processing Record  205 |  Vanimo
# Processing Record  206 |  Georgetown
# Processing Record  207 |  Kokubu
# City not found, skip...
# Processing Record  208 |  Sao Joao da Barra
# Processing Record  209 |  Denpasar
# Processing Record  210 |  Honiara
# City not found, skip...
# Processing Record  211 |  Tilichiki
# Processing Record  212 |  Ano Mera
# Processing Record  213 |  Hobyo
# Processing Record  214 |  Longyearbyen
# Processing Record  215 |  Rio Gallegos
# Processing Record  216 |  Mar del Plata
# Processing Record  217 |  Pontianak
# Processing Record  218 |  Cognac
# Processing Record  219 |  Guerrero Negro
# Processing Record  220 |  Lebu
# Processing Record  221 |  Souillac
# Processing Record  222 |  Kaeo
# Processing Record  223 |  Lompoc
# Processing Record  224 |  Ananas
# Processing Record  225 |  Sitka
# Processing Record  226 |  Sola
# Processing Record  227 |  Pangnirtung
# Processing Record  228 |  Numan
# Processing Record  229 |  Potrero del Llano
# Processing Record  230 |  Fortuna
# City not found, skip...
# Processing Record  231 |  Bintulu
# Processing Record  232 |  Severo-Kurilsk
# Processing Record  233 |  Cabo San Lucas
# Processing Record  234 |  Katobu
# City not found, skip...
# Processing Record  235 |  Aksha
# Processing Record  236 |  Bombay
# Processing Record  237 |  Scottsbluff
# Processing Record  238 |  Bilibino
# Processing Record  239 |  Ndjole
# Processing Record  240 |  Portel
# Processing Record  241 |  Saint-Augustin
# Processing Record  242 |  Victoria
# Processing Record  243 |  Forssa
# Processing Record  244 |  Verkhnyaya Inta
# Processing Record  245 |  Porto Novo
# Processing Record  246 |  Banswara
# Processing Record  247 |  Padang
# Processing Record  248 |  Lavumisa
# Processing Record  249 |  Teya
# Processing Record  250 |  Torbat-e Jam
# Processing Record  251 |  Lerwick
# Processing Record  252 |  Saskylakh
# Processing Record  253 |  Tra Vinh
# Processing Record  254 |  Namibe
# Processing Record  255 |  Tarakan
# Processing Record  256 |  Tessalit
# Processing Record  257 |  Yokadouma
# Processing Record  258 |  Ouallam
# City not found, skip...
# Processing Record  259 |  Cap Malheureux
# Processing Record  260 |  Pinheiro Machado
# Processing Record  261 |  Esperance
# Processing Record  262 |  Tabou
# Processing Record  263 |  Erenhot
# Processing Record  264 |  Lulea
# Processing Record  265 |  Mozarlandia
# Processing Record  266 |  Nanortalik
# Processing Record  267 |  Kununurra
# Processing Record  268 |  Launceston
# Processing Record  269 |  Bajil
# City not found, skip...
# Processing Record  270 |  Chuy
# Processing Record  271 |  Oytal
# Processing Record  272 |  Amparafaravola
# Processing Record  273 |  Shingu
# Processing Record  274 |  Horsham
# Processing Record  275 |  Antonina
# Processing Record  276 |  Okhotsk
# Processing Record  277 |  Cidreira
# Processing Record  278 |  Maynooth
# Processing Record  279 |  Qaqortoq
# Processing Record  280 |  Anamur
# Processing Record  281 |  Vieux-Habitants
# Processing Record  282 |  Marathon
# Processing Record  283 |  Lokosovo
# City not found, skip...
# Processing Record  284 |  San Jose
# City not found, skip...
# Processing Record  285 |  Nalut
# Processing Record  286 |  America Dourada
# Processing Record  287 |  Lasa
# Processing Record  288 |  Morondava
# Processing Record  289 |  Te Anau
# Processing Record  290 |  Plettenberg Bay
# Processing Record  291 |  Tura
# Processing Record  292 |  Moerai
# Processing Record  293 |  Kingori
# Processing Record  294 |  Sorland
# Processing Record  295 |  Caetite
# Processing Record  296 |  East London
# Processing Record  297 |  Caravelas
# Processing Record  298 |  Ust-Nera
# Processing Record  299 |  Lincoln
# Processing Record  300 |  Kota Belud
# Processing Record  301 |  Alofi
# City not found, skip...
# Processing Record  302 |  Kiunga
# Processing Record  303 |  Timbuktu
# Processing Record  304 |  Ponta do Sol
# Processing Record  305 |  Vesoul
# Processing Record  306 |  Homer
# Processing Record  307 |  Port Hedland
# Processing Record  308 |  Cleburne
# City not found, skip...
# Processing Record  309 |  Alice Springs
# Processing Record  310 |  Lufilufi
# Processing Record  311 |  Abu Kamal
# City not found, skip...
# Processing Record  312 |  Kayerkan
# Processing Record  313 |  Kaitangata
# Processing Record  314 |  Zaraza
# Processing Record  315 |  Houma
# Processing Record  316 |  Cayenne
# Processing Record  317 |  Kendari
# Processing Record  318 |  Athabasca
# Processing Record  319 |  Provideniya
# Processing Record  320 |  Port Elizabeth
# Processing Record  321 |  Bilma
# Processing Record  322 |  Bissora
# Processing Record  323 |  Saginaw
# Processing Record  324 |  Nakusp
# Processing Record  325 |  Ola
# Processing Record  326 |  Shenjiamen
# Processing Record  327 |  Exeter
# Processing Record  328 |  Karoi
# Processing Record  329 |  Venice
# Processing Record  330 |  Rocha
# Processing Record  331 |  Birao
# Processing Record  332 |  Veydelevka
# Processing Record  333 |  San Vicente
# Processing Record  334 |  Suluq
# Processing Record  335 |  Port-Gentil
# Processing Record  336 |  Taywarah
# Processing Record  337 |  Bijar
# Processing Record  338 |  Boyuibe
# Processing Record  339 |  Thaba-Tseka
# Processing Record  340 |  Kieta
# Processing Record  341 |  Kalianget
# Processing Record  342 |  Saldanha
# Processing Record  343 |  Kodiak
# City not found, skip...
# Processing Record  344 |  Genhe
# Processing Record  345 |  Vostok
# Processing Record  346 |  Mopipi
# Processing Record  347 |  Buraydah
# Processing Record  348 |  Picayune
# Processing Record  349 |  Saint Stephen
# Processing Record  350 |  Scarborough
# Processing Record  351 |  Socorro
# Processing Record  352 |  Nogliki
# Processing Record  353 |  Turbat
# Processing Record  354 |  Vung Tau
# City not found, skip...
# Processing Record  355 |  Wellington
# Processing Record  356 |  Anadyr
# Processing Record  357 |  Lavrentiya
# City not found, skip...
# Processing Record  358 |  Touros
# Processing Record  359 |  Garowe
# City not found, skip...
# Processing Record  360 |  Mugur-Aksy
# Processing Record  361 |  San Cristobal
# Processing Record  362 |  Grindavik
# Processing Record  363 |  Mnogovershinnyy
# City not found, skip...
# Processing Record  364 |  Buzmeyin
# Processing Record  365 |  Tigil
# Processing Record  366 |  Conde
# Processing Record  367 |  Chopinzinho
# Processing Record  368 |  Quetta
# Processing Record  369 |  Ilebo
# Processing Record  370 |  Namatanai
# Processing Record  371 |  West Bay
# Processing Record  372 |  Porbandar
# Processing Record  373 |  Hofn
# Processing Record  374 |  Panaba
# Processing Record  375 |  Ambilobe
# Processing Record  376 |  Pacific Grove
# Processing Record  377 |  Flinders
# Processing Record  378 |  Redlands
# Processing Record  379 |  Buala
# Processing Record  380 |  Geraldton
# City not found, skip...
# Processing Record  381 |  Macklin
# Processing Record  382 |  Hamilton
# Processing Record  383 |  Tete
# Processing Record  384 |  Dargaville
# Processing Record  385 |  Narsaq
# City not found, skip...
# Processing Record  386 |  Belaya Gora
# Processing Record  387 |  Pochutla
# Processing Record  388 |  Bella Union
# Processing Record  389 |  Khani
# Processing Record  390 |  Saint-Georges
# Processing Record  391 |  Port Augusta
# Processing Record  392 |  Peace River
# Processing Record  393 |  Gejiu
# Processing Record  394 |  Rawson
# Processing Record  395 |  Contai
# Processing Record  396 |  Russell
# Processing Record  397 |  Foumban
# City not found, skip...
# Processing Record  398 |  Itarema
# Processing Record  399 |  Palu
# Processing Record  400 |  Ostrovnoy
# Processing Record  401 |  Williams Lake
# Processing Record  402 |  Zhengjiatun
# Processing Record  403 |  Ketchikan
# Processing Record  404 |  Ornskoldsvik
# City not found, skip...
# Processing Record  405 |  Eidfjord
# Processing Record  406 |  Agirish
# Processing Record  407 |  Vanavara
# Processing Record  408 |  Izhma
# Processing Record  409 |  Kizukuri
# Processing Record  410 |  Bauchi
# Processing Record  411 |  Constantine
# Processing Record  412 |  Paradise
# Processing Record  413 |  Shubarkuduk
# Processing Record  414 |  Ancud
# Processing Record  415 |  Jumla
# Processing Record  416 |  Port-Cartier
# Processing Record  417 |  Monrovia
# Processing Record  418 |  Miri
# Processing Record  419 |  Broken Hill
# Processing Record  420 |  Raudeberg
# Processing Record  421 |  Blythe
# Processing Record  422 |  Bathsheba
# Processing Record  423 |  Oksfjord
# Processing Record  424 |  Labuhan
# Processing Record  425 |  Wichita Falls
# Processing Record  426 |  Narodychi
# Processing Record  427 |  Platteville
# Processing Record  428 |  Gairatganj
# Processing Record  429 |  Bordighera
# City not found, skip...
# Processing Record  430 |  Vao
# Processing Record  431 |  Waingapu
# Processing Record  432 |  Sept-Iles
# Processing Record  433 |  Channel-Port aux Basques
# Processing Record  434 |  Coahuayana
# Processing Record  435 |  Khandyga
# Processing Record  436 |  Petrovskoye
# Processing Record  437 |  Erdenet
# Processing Record  438 |  Caala
# Processing Record  439 |  Aykhal
# City not found, skip...
# Processing Record  440 |  Drovyanaya
# Processing Record  441 |  Belen
# Processing Record  442 |  Hasaki
# Processing Record  443 |  Nome
# Processing Record  444 |  Puerto Narino
# Processing Record  445 |  Adrar
# Processing Record  446 |  Gamba
# Processing Record  447 |  Zheleznodorozhnyy
# Processing Record  448 |  Hue
# Processing Record  449 |  Inirida
# Processing Record  450 |  Hervey Bay
# Processing Record  451 |  Katsuura
# Processing Record  452 |  Rundu
# Processing Record  453 |  Coquimbo
# Processing Record  454 |  Vikhorevka
# Processing Record  455 |  Khorinsk
# Processing Record  456 |  Tiruppuvanam
# Processing Record  457 |  Cartagena
# Processing Record  458 |  Jijiga
# Processing Record  459 |  Laives
# Processing Record  460 |  Barmer
# City not found, skip...
# Processing Record  461 |  San Nicolas
# Processing Record  462 |  Amapa
# Processing Record  463 |  Aksu
# Processing Record  464 |  Boone
# Processing Record  465 |  Bulungu
# Processing Record  466 |  Kirensk
# Processing Record  467 |  Magdagachi
# Processing Record  468 |  Umm Kaddadah
# Processing Record  469 |  Maltahohe
# Processing Record  470 |  Itoman
# Processing Record  471 |  Sistranda
# Processing Record  472 |  Zhigansk
# Processing Record  473 |  Port Macquarie
# Processing Record  474 |  Smithville
# Processing Record  475 |  Tranas
# Processing Record  476 |  Bell Ville
# Processing Record  477 |  Klyuchi
# City not found, skip...
# Processing Record  478 |  Yaan
# Processing Record  479 |  Aripuana
# City not found, skip...
# Processing Record  480 |  Saint-Paul
# Processing Record  481 |  Chara
# City not found, skip...
# Processing Record  482 |  Igrim
# Processing Record  483 |  Honningsvag
# Processing Record  484 |  Skaudvile
# City not found, skip...
# Processing Record  485 |  Daru
# Processing Record  486 |  Pervomayskiy
# Processing Record  487 |  Ayorou
# Processing Record  488 |  Kuruman
# Processing Record  489 |  Champasak
# Processing Record  490 |  Road Town
# Processing Record  491 |  Srednekolymsk
# City not found, skip...
# Processing Record  492 |  High Rock
# Processing Record  493 |  Yinchuan
# Processing Record  494 |  Dunedin
# Processing Record  495 |  Moussoro
# Processing Record  496 |  Atar
# Processing Record  497 |  Amga
# Processing Record  498 |  Kainantu
# Processing Record  499 |  Mitu
# Processing Record  500 |  Elizabeth City
# Processing Record  501 |  Estelle
# Processing Record  502 |  San Ramon de la Nueva Oran
# Processing Record  503 |  Charyshskoye
# Processing Record  504 |  Liberia
# Processing Record  505 |  Portland
# City not found, skip...
# Processing Record  506 |  Uvinza
# Processing Record  507 |  Montevideo
# Processing Record  508 |  Taybad
# Processing Record  509 |  Castrovillari
# Processing Record  510 |  Ahipara
# Processing Record  511 |  Yulara
# Processing Record  512 |  Kimbe
# Processing Record  513 |  Shirokiy
# Processing Record  514 |  Sao Jose da Coroa Grande
# Processing Record  515 |  Farafangana
# City not found, skip...
# Processing Record  516 |  Awash
# City not found, skip...
# Processing Record  517 |  Salym
# Processing Record  518 |  Puerto Ayacucho
# Processing Record  519 |  Wladyslawowo
# Processing Record  520 |  Vestmannaeyjar
# Processing Record  521 |  Taltal
# Processing Record  522 |  Tezu
# Processing Record  523 |  Oriximina
# Processing Record  524 |  Yumen
# City not found, skip...
# Processing Record  525 |  Beyneu
# Processing Record  526 |  Asosa
# Processing Record  527 |  Copiapo
# Processing Record  528 |  Tara
# Processing Record  529 |  Ubaitaba
# Processing Record  530 |  Arman
# Processing Record  531 |  Mackenzie
# Processing Record  532 |  Krasni Okny
# Processing Record  533 |  Freeport
# City not found, skip...
# Processing Record  534 |  Auki
# City not found, skip...
# Processing Record  535 |  Kholodnyy
# Processing Record  536 |  Coos Bay
# Processing Record  537 |  San Jose de Gracia
# Processing Record  538 |  Vardo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#owmCities_df.to_csv("output_data_file", index=False, header=True)

# %%
file="output_data_file"
weather_data=pd.read_csv(file)
weather_data.count()
# Out:
# City          538
# Cloudiness    538
# Country       535
# Date          538
# Humidity      538
# Lat           538
# Lng           538
# Max Temp      538
# Wind Speed    538
# dtype: int64

# %%
weather_data["Max Temp"].max()
weather_data["Max Temp"].min()
weather_data["Lat"].max()
weather_data["Lat"].min()
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Busselton           0      AU  1541293456       100 -33.64  115.35
# 1          Hilo          40      US  1541289360        69  19.71 -155.08
# 2         Vaini          56      IN  1541293456        95  15.34   74.49
# 3  Kruisfontein           0      ZA  1541293249        70 -34.00   24.73
# 4     Upernavik           8      GL  1541291680       100  72.79  -56.15
#
#    Max Temp  Wind Speed
# 0     62.34       11.59
# 1     82.04       11.41
# 2     71.34        3.60
# 3     65.09       11.14
# 4     19.50       11.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Scatter plot for Latitude vs. Temperature
plt.scatter(weather_data["Lat"], 
            weather_data["Max Temp"], c="blue", edgecolor="black", 
            linewidths=1, marker="o", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature (11/03/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 80])
plt.ylim([-30, 100])

# Save the figure
plt.savefig("Latitude_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_data["Humidity"].max()
weather_data["Humidity"].min()
#weather_data["Lat"].max()
#weather_data["Lat"].min()
#weather_data.head()
# Out:
# 7

# %%
#Scatter plot for Latitude vs. Humidity
plt.scatter(weather_data["Lat"], 
            weather_data["Humidity"], c="blue", edgecolor="black", 
            linewidths=1, marker="o", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity (11/03/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 90])
plt.ylim([0, 110])

# Save the figure
plt.savefig("Latitude_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_data["Cloudiness"].max()
weather_data["Cloudiness"].min()
#weather_data["Lat"].max()
#weather_data["Lat"].min()
#weather_data.head()
# Out:
# 0

# %%
#Scatter plot for Latitude vs. Cloudiness
plt.scatter(weather_data["Lat"], 
            weather_data["Cloudiness"], c="blue", edgecolor="black", 
            linewidths=1, marker="o", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (11/03/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 90])
plt.ylim([-10, 110])

# Save the figure
plt.savefig("Latitude_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_data["Wind Speed"].max()
weather_data["Wind Speed"].min()
#weather_data["Lat"].max()
#weather_data["Lat"].min()
#weather_data.head()
# Out:
# 0.29

# %%
#Scatter plot for Latitude vs. Cloudiness
plt.scatter(weather_data["Lat"], 
            weather_data["Wind Speed"], c="blue", edgecolor="black", 
            linewidths=1, marker="o", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed (11/03/18)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 90])
plt.ylim([-10, 40])

# Save the figure
plt.savefig("Latitude_Wind_Speed.png")

# Show plot
plt.show()
